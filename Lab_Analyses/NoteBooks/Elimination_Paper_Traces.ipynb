# %%
# %matplotlib inline
from Lab_Analyses.NoteBooks.matlab_spine_properties import matlab_spine_properties

data_dir = r"Z:\People\Nathan\Elim Spine Manuscript\GluSnFR3_data\GreenCh"

save=False


matlab_spine_properties(data_dir, smooth=True, save=True)
# Out:
# JW083_Aligned
# JW090_Aligned
# JW092_Aligned
# JW129_Aligned
# JW130_Aligned
# JW153_Aligned
# JW168_Aligned
# C:\Users\Jake\Documents\Anaconda3\envs\analysis_env\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       4 data_dir = r"Z:\People\Nathan\Elim Spine Manuscript\GluSnFR3_data\GreenCh"
#       6 save=False
# ----> 9 matlab_spine_properties(data_dir, smooth=True, save=True)
#
# File c:\users\jake\desktop\python_code\lab_analyses\Lab_Analyses\NoteBooks\matlab_spine_properties.py:254, in matlab_spine_properties(data_dir, smooth, save)
#     252 non_nan_amp = np.nonzero(~np.isnan(all_event_amplitudes))[0]
# ...

# %%
import numpy as np
a = np.nan

if a < 1.5:
    print("True")
else:
    print("False")
# Out:
# False

# %%
a = np.array([True, False, True, False])
b = np.array([True, True, False, False])

a * b
# Out:
# array([ True, False, False, False])
